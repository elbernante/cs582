# %%
import glob, os, pickle
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
from random import shuffle
# %matplotlib inline

# %%
LOG_FILE = "output/history_log.pkl"
def get_log(filename):
    with open(filename, 'rb') as f:
        log_file = pickle.load(f)
    return log_file

# %%
log_file = get_log(LOG_FILE)

# %%
df = pd.DataFrame.from_dict(log_file)
df.set_index('epoch', inplace=True)

# %%
df.tail()
# Out:
#        dice_coef  f1_score      loss  val_dice_coef  val_f1_score  val_loss
# epoch
# 5       0.288217  0.291906 -0.288217       0.302261      0.304638 -0.302261
# 6       0.336814  0.338666 -0.336814       0.453274      0.455057 -0.453274
# 7       0.366708  0.368226 -0.366708       0.418813      0.419608 -0.418813
# 8       0.392745  0.393731 -0.392745       0.493941      0.494915 -0.493941
# 9       0.420131  0.421027 -0.420131       0.511777      0.512636 -0.511777

# %%
loss = df[['loss', 'val_loss']]
loss.plot(figsize=(15,5), title="Loss")

# %%
dice = df[['dice_coef', 'val_dice_coef']]
dice.plot(figsize=(15,5), title="Dice Coefficient")

# %%
f1 = df[['f1_score', 'val_f1_score']]
f1.plot(figsize=(15,5), title="F1 Score")
