# %%
import glob, os, pickle
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
from random import shuffle
# %matplotlib inline

# %%
LOG_FILE = "output/history_log.pkl"
def get_log(filename):
    with open(filename, 'rb') as f:
        log_file = pickle.load(f)
    return log_file

# %%
log_file = get_log(LOG_FILE)

# %%
df = pd.DataFrame.from_dict(log_file)
df.set_index('epoch', inplace=True)

# %%
df.tail()
# Out:
#        dice_coef  f05_score  f1_score  f2_score      loss  val_dice_coef  \
# epoch
# 15      0.647012   0.647105  0.647376  0.650171 -0.647012       0.651044
# 16      0.645308   0.644451  0.645651  0.651423 -0.645308       0.671554
# 17      0.650617   0.649239  0.650898  0.655870 -0.650617       0.667144
# 18      0.656671   0.661220  0.656997  0.656111 -0.656671       0.637931
# 19      0.653602   0.652869  0.653921  0.659410 -0.653602       0.672353
#
#        val_f05_score  val_f1_score  val_f2_score  val_loss
# epoch
# 15          0.606211      0.651289      0.705562 -0.651044
# 16          0.678838      0.671816      0.667055 -0.671554
# 17          0.699597      0.667470      0.639534 -0.667144
# 18          0.703717      0.637970      0.584968 -0.637931
# 19          0.698442      0.672623      0.649979 -0.672353

# %%
loss = df[['loss', 'val_loss']]
loss.plot(figsize=(15,5), title="Loss")

# %%
dice = df[['dice_coef', 'val_dice_coef']]
dice.plot(figsize=(15,5), title="Dice Coefficient")

# %%
f1 = df[['f1_score', 'val_f1_score']]
f1.plot(figsize=(15,5), title="F1 Score")

# %%
f2 = df[['f2_score', 'val_f2_score']]
f2.plot(figsize=(15,5), title="F2 Score")

# %%
f05 = df[['f05_score', 'val_f05_score']]
f05.plot(figsize=(15,5), title="F05 Score")
